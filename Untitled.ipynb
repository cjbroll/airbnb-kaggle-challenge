# %%
import pandas as pd
import numpy as np

# %%
raw = pd.read_csv('best_user_records.csv')

# %%
raw = raw.drop(['Unnamed: 0', 'id', 'date_account_created', 'timestamp_first_active', 'date_first_booking'], axis=1)

# %%
raw.head().T
# Out:
#                                         0              1            2  \
# gender                               MALE      -unknown-         MALE
# age                                    39             36           36
# signup_method                       basic          basic        basic
# signup_flow                             0              0            0
# language                               en             en           en
# affiliate_channel                  direct         direct       direct
# affiliate_provider                 direct         direct       direct
# first_affiliate_tracked         untracked         linked    untracked
# signup_app                            Web            Web          Web
# first_device_type             Mac Desktop           iPad  Mac Desktop
# first_browser                      Chrome  Mobile Safari       Chrome
# country_destination                 other             US           US
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
raw.head().T
# Out:
#                                         0              1            2  \
# gender                               MALE      -unknown-         MALE
# age                                    39             36           36
# signup_method                       basic          basic        basic
# signup_flow                             0              0            0
# language                               en             en           en
# affiliate_channel                  direct         direct       direct
# affiliate_provider                 direct         direct       direct
# first_affiliate_tracked         untracked         linked    untracked
# signup_app                            Web            Web          Web
# first_device_type             Mac Desktop           iPad  Mac Desktop
# first_browser                      Chrome  Mobile Safari       Chrome
# country_destination                 other             US           US
# ...

# %%
log = LogisticRegression()

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(fitted, X, y, cv=5)
